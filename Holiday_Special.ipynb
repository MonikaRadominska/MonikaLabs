# %% [markdown]
# ## TOC:
# * [Description](#first-bullet)
# * [Christmas Photo](#second-bullet)
# * [Berlin at Christmas](#third-bullet)
# * [Christmas favorites](#fourth-bullet)
# * [Christmas Video](#fifth-bullet)

# %% [markdown]
# <h1 style="color:red;">My moms favorite holiday: aka Christmas</h1></h1>

# %% [markdown]
# # Description <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# <h2>This notebook showcases my moms favorite season and holiday</h2>

# %%
name = input("Write name: ")
# Out:
# Write name: Margo

# %%
holiday = input("What is her favorite holiday: ")
# Out:
# What is her favorite holiday: Christmas

# %% [markdown]
# # Christmas Photo <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# <h2>A photo of my mom and dad during Christmas</h2>

# %% [markdown]
# ![christmas2-2.jpg](attachment:christmas2-2.jpg)

# %% [markdown]
# # Berlin at Christmas <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# <h2>They love to come to Germany for Christmas or we travel to England</h2>

# %% [markdown]
# ![berlin-christmas-markets-fb.jpg](attachment:berlin-christmas-markets-fb.jpg)

# %% [markdown]
# # Christmas Favorites <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# <h2>Her favorite things to do during Christmas are:<h2>

# %% [markdown]
# <ol>
#     <li>Visit Christmas Markets</li>
#     <li>Make me do the cooking</li>
#     <li>Explore new cities</li>
# </ol>

# %% [markdown]
# # Christmas Video <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# A nice example of the Berlin Christmas Markets [Youtube](https://youtu.be/o8FYHXQbo1A).
